# %%
from db_util import get_db
import pandas as pd

db = get_db()

# %%
sql = "SHOW TABLES"
df = pd.read_sql(sql, db)
# Out:
# /var/folders/7l/yp5d25zx7nb_92wbp8w2b0dw0000gn/T/ipykernel_70307/1302501115.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, db)

# %%
df
# Out:
#   Tables_in_student_mgmt
# 0               students

# %%
sql = "SELECT * FROM students"
df = pd.read_sql(sql,db)
# Out:
# /var/folders/7l/yp5d25zx7nb_92wbp8w2b0dw0000gn/T/ipykernel_70307/3088303204.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql,db)

# %%
df
# Out:
#    id    name gender       birth  english  math  korean
# 0   1    dave    man  1983-07-16       90    80      71
# 1   2  minsun  woman  1982-10-16       30    88      60
# 2   3   david    man  1982-12-10       78    77      30
# 3   4    jade    man  1979-11-01       45    66      20
# 4   5    jane    man  1990-11-12       65    32      90
# 5   6    wage  woman  1982-01-13       76    30      80
# 6   7    tina  woman  1982-12-03       87    62      71

# %%
type(df['math'][0]) # 테이블의 컬럼 형식을 그대로 유지
# Out:
# numpy.int64

# %%
df.to_csv('students.csv', sep=',', index=False, encoding='utf-8')
df
# Out:
#    id    name gender       birth  english  math  korean
# 0   1    dave    man  1983-07-16       90    80      71
# 1   2  minsun  woman  1982-10-16       30    88      60
# 2   3   david    man  1982-12-10       78    77      30
# 3   4    jade    man  1979-11-01       45    66      20
# 4   5    jane    man  1990-11-12       65    32      90
# 5   6    wage  woman  1982-01-13       76    30      80
# 6   7    tina  woman  1982-12-03       87    62      71

# %%
db.close()
